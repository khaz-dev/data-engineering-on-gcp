# %%
host = '34.101.145.162'
port = 5432
database = 'khaz_retail_db'
user = 'khaz_retail_user'
password = 'postgres'

# %%
conn_uri = f'postgresql://{user}:{password}@{host}:{port}/{database}'

# %%
import pandas as pd

# %%
query = '''
    SELECT * FROM information_schema.tables
    WHERE table_catalog = 'khaz_retail_db'
        AND table_schema = 'public'
'''

# %%
pd.read_sql(query, conn_uri)
# Out:
#     table_catalog table_schema          table_name  table_type  \
# 0  khaz_retail_db       public         departments  BASE TABLE
# 1  khaz_retail_db       public          categories  BASE TABLE
# 2  khaz_retail_db       public            products  BASE TABLE
# 3  khaz_retail_db       public           customers  BASE TABLE
# 4  khaz_retail_db       public              orders  BASE TABLE
# 5  khaz_retail_db       public         order_items  BASE TABLE
# 6  khaz_retail_db       public  daily_status_count  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# ...

# %%
pd.read_sql('orders', conn_uri)
# Out:
#        order_id order_date  order_customer_id     order_status
# 0             1 2013-07-25              11599           CLOSED
# 1             2 2013-07-25                256  PENDING_PAYMENT
# 2             3 2013-07-25              12111         COMPLETE
# 3             4 2013-07-25               8827           CLOSED
# 4             5 2013-07-25              11318         COMPLETE
# ...         ...        ...                ...              ...
# 68878     68879 2014-07-09                778         COMPLETE
# 68879     68880 2014-07-13               1117         COMPLETE
# 68880     68881 2014-07-19               2518  PENDING_PAYMENT
# 68881     68882 2014-07-22              10000          ON_HOLD
# 68882     68883 2014-07-23               5533         COMPLETE
#
# [68883 rows x 4 columns]
